# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

from sksurv.linear_model import CoxPHSurvivalAnalysis, CoxnetSurvivalAnalysis
from sksurv.preprocessing import OneHotEncoder
from sksurv.datasets import load_breast_cancer
from sksurv.nonparametric import kaplan_meier_estimator

from sklearn.model_selection import GridSearchCV, KFold
from sklearn.exceptions import ConvergenceWarning
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('clinical-train.csv')
df.head()
# Out:
#    Num      Patient  surv_status  surv_time  DF_surv_status  DF_surv_time  \
# 0    1  SICK0000022            0  20.866667               0     11.233333
# 1    2  SICK0000027            1  74.666667               0     31.600000
# 2    3  SICK0000053            1  58.633333               1     58.633333
# 3    4  SICK0000085            1  58.533333               1     58.533333
# 4    5  SICK0000213            0  40.433333               0     13.766667
#
#    DM_status    DM_time  IM_status    IM_time  ...  clinical_44  clinical_45  \
# 0          1  11.233333          0  20.866667  ...            1            0
# 1          0  74.666667          0  74.666667  ...            0            0
# 2          0  58.633333          0  58.633333  ...            1            1
# 3          0  58.533333          0  58.533333  ...            0            0
# 4          1  13.766667          1  13.766667  ...            1            0
#
#    clinical_46  clinical_47  clinical_48  clinical_49  clinical_50  \
# 0            3            0         60.0            1            0
# 1            3            0         80.0            0            0
# 2            2            0         60.0            1            0
# 3            3            1         70.0            0            1
# 4            3            1         50.0            0            1
#
#    clinical_51  clinical_52  clinical_53
# 0          253          417     0.606715
# 1          151          261     0.578544
# 2          178          349     0.510029
# 3          236          248     0.951613
# 4          223          277     0.805054
#
# [5 rows x 63 columns]

# %%
df["surv_status"]=df["surv_status"].astype(bool)
df["surv_status"]
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 278     True
# 279     True
# 280     True
# 281     True
# 282     True
# Name: surv_status, Length: 283, dtype: bool

# %%
df["DF_surv_status"]=df["DF_surv_status"].astype(bool)
df["DF_surv_status"]
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 278     True
# 279     True
# 280     True
# 281     True
# 282     True
# Name: DF_surv_status, Length: 283, dtype: bool

# %%
data=df.iloc[0:, 2:4]
data1=df.iloc[0:, 4:6]
X=df.iloc[0:, 10:]

y=data.to_records(index=False)
y1=data1.to_records(index=False)
X=OneHotEncoder().fit_transform(X)

# %%
y.shape
# Out:
# (283,)

# %%
X
# Out:
#      clinical_01  clinical_02  clinical_03  clinical_04  clinical_05  \
# 0              1           45            2            1            1
# 1              1           39            1            1            0
# 2              1           41            2            1            0
# 3              1           41            2            1            0
# 4              1           40            1            1            0
# ..           ...          ...          ...          ...          ...
# 278            1           42            2            1            0
# 279            1           48            2            1            0
# 280            2           65            3            1            1
# 281            1           48            2            1            0
# 282            1           50            2            1            0
#
#      clinical_06  clinical_07  clinical_08  clinical_09  clinical_10  ...  \
# 0              2            1            2            0            1  ...
# 1              1            0            1            0            1  ...
# 2              2            3            2            1            1  ...
# 3              2            0            2            0            1  ...
# 4              1            0            1            0            1  ...
# ..           ...          ...          ...          ...          ...  ...
# 278            2            0            2            0            1  ...
# 279            2            0            2            0            1  ...
# 280            2            1            2            0            1  ...
# 281            2            1            2            0            1  ...
# 282            2            0            2            0            1  ...
#
#      clinical_44  clinical_45  clinical_46  clinical_47  clinical_48  \
# 0              1            0            3            0         60.0
# 1              0            0            3            0         80.0
# 2              1            1            2            0         60.0
# 3              0            0            3            1         70.0
# 4              1            0            3            1         50.0
# ..           ...          ...          ...          ...          ...
# 278            1            0            3            0         70.0
# 279            1            0            3            1         75.0
# 280            1            0            3            2         30.0
# 281            1            0            3            0         80.0
# 282            1            1            3            1         30.0
#
#      clinical_49  clinical_50  clinical_51  clinical_52  clinical_53
# 0              1            0          253          417     0.606715
# 1              0            0          151          261     0.578544
# 2              1            0          178          349     0.510029
# 3              0            1          236          248     0.951613
# 4              0            1          223          277     0.805054
# ..           ...          ...          ...          ...          ...
# 278            0            0          252          509     0.495088
# 279            0            1          304          389     0.781491
# 280            1            0          185          301     0.614618
# 281            1            0          276          692     0.398844
# 282            0            0          232          680     0.341176
#
# [283 rows x 53 columns]

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
X_std = stdsc.fit_transform(X)
print(X_std.shape)

X1 = pd.DataFrame(X_std)
# Out:
# (283, 53)

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X_mms = mms.fit_transform(X)
print(X_mms.shape)

X2 = pd.DataFrame(X_mms)
# Out:
# (283, 53)

# %% [markdown]
# ## surve time X1

# %%
def plot_coefficients(coefs, n_highlight):
    _, ax = plt.subplots(figsize=(9, 6))
    n_features = coefs.shape[0]
    alphas = coefs.columns
    for row in coefs.itertuples():
        ax.semilogx(alphas, row[1:], "-", label=row.Index)

    alpha_min = alphas.min()
    top_coefs = coefs.loc[:, alpha_min].map(abs).sort_values().tail(n_highlight)
    for name in top_coefs.index:
        coef = coefs.loc[name, alpha_min]
        #plt.text(
            #alpha_min, coef, name + "   ",
            #horizontalalignment="right",
            #verticalalignment="center"
        #)

    ax.yaxis.set_label_position("right")
    ax.yaxis.tick_right()
    ax.grid(True)
    ax.set_xlabel("alpha")
    ax.set_ylabel("coefficient")

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X1, y)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('fig1.jpg', dpi=1200)
plt.show()

# %% [markdown]
# ## surve time X2

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X2, y)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('fig2.jpg', dpi=1200)
plt.show()

# %% [markdown]
# ## surve time X1 & X2

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.exceptions import FitFailedWarning


coxnet_pipe = make_pipeline(
    StandardScaler(),
    CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01, max_iter=100000)
)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FitFailedWarning)
coxnet_pipe.fit(X1, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('coxnetsurvivalanalysis',
#                  CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=1.0))])

# %%
estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
cv = KFold(n_splits=5, shuffle=True, random_state=0)
gcv = GridSearchCV(
    make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=1.0)),
    param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
    cv=cv,
    error_score=0.5,
    n_jobs=4).fit(X1, y)

cv_results = pd.DataFrame(gcv.cv_results_)

# %%
alphas = cv_results.param_coxnetsurvivalanalysis__alphas.map(lambda x: x[0])
mean = cv_results.mean_test_score
std = cv_results.std_test_score

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(alphas, mean)
ax.fill_between(alphas, mean - std, mean + std, alpha=.15)
ax.set_xscale("log")
ax.set_ylabel("concordance index")
ax.set_xlabel("alpha")
ax.axvline(gcv.best_params_["coxnetsurvivalanalysis__alphas"][0], c="C1")
ax.axhline(0.5, color="grey", linestyle="--")
ax.grid(True)

#plt.savefig('fig3.jpg', dpi=1200)
plt.show()

# %%
best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
best_coefs = pd.DataFrame(
    best_model.coef_,
    index=X.columns,
    columns=["coefficient"]
)

non_zero = np.sum(best_coefs.iloc[:, 0] != 0)
print("Number of non-zero coefficients: {}".format(non_zero))

non_zero_coefs = best_coefs.query("coefficient != 0")
coef_order = non_zero_coefs.abs().sort_values("coefficient").index

_, ax = plt.subplots(figsize=(8, 8))
non_zero_coefs.loc[coef_order].plot.barh(ax=ax, legend=False)
ax.set_xlabel("coefficient")
ax.grid(True)

#plt.savefig('fig4.jpg', dpi=1200)
plt.show()
# Out:
# Number of non-zero coefficients: 6

# %%
non_zero_coefs
# Out:
#              coefficient
# clinical_12    -0.158226
# clinical_13     0.101529
# clinical_14    -0.015181
# clinical_16    -0.038802
# clinical_20     0.088494
# clinical_48     0.166591

# %%
coef_order
# Out:
# Index(['clinical_14', 'clinical_16', 'clinical_20', 'clinical_13',
#        'clinical_12', 'clinical_48'],
#       dtype='object')

# %%
gcv.best_params_["coxnetsurvivalanalysis__alphas"][0]
# Out:
# 0.06909927459216013

# %% [markdown]
# ## DF surve time

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X1, y1)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('fig_1.jpg', dpi=1200)
plt.show()

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X2, y1)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('fig_2.jpg', dpi=1200)
plt.show()

# %%
coxnet_pipe = make_pipeline(
    StandardScaler(),
    CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01, max_iter=100000)
)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FitFailedWarning)
coxnet_pipe.fit(X1, y1)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('coxnetsurvivalanalysis',
#                  CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=1.0))])

# %%
estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
cv = KFold(n_splits=5, shuffle=True, random_state=0)
gcv = GridSearchCV(
    make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=1.0)),
    param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
    cv=cv,
    error_score=0.5,
    n_jobs=4).fit(X1, y1)

cv_results = pd.DataFrame(gcv.cv_results_)

# %%
alphas = cv_results.param_coxnetsurvivalanalysis__alphas.map(lambda x: x[0])
mean = cv_results.mean_test_score
std = cv_results.std_test_score

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(alphas, mean)
ax.fill_between(alphas, mean - std, mean + std, alpha=.15)
ax.set_xscale("log")
ax.set_ylabel("concordance index")
ax.set_xlabel("alpha")
ax.axvline(gcv.best_params_["coxnetsurvivalanalysis__alphas"][0], c="C1")
ax.axhline(0.5, color="grey", linestyle="--")
ax.grid(True)

#plt.savefig('fig_3.jpg', dpi=1200)
plt.show()

# %%
best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
best_coefs = pd.DataFrame(
    best_model.coef_,
    index=X.columns,
    columns=["coefficient"]
)

non_zero = np.sum(best_coefs.iloc[:, 0] != 0)
print("Number of non-zero coefficients: {}".format(non_zero))

non_zero_coefs = best_coefs.query("coefficient != 0")
coef_order = non_zero_coefs.abs().sort_values("coefficient").index

_, ax = plt.subplots(figsize=(8, 8))
non_zero_coefs.loc[coef_order].plot.barh(ax=ax, legend=False)
ax.set_xlabel("coefficient")
ax.grid(True)

#plt.savefig('fig_4.jpg', dpi=1200)
plt.show()
# Out:
# Number of non-zero coefficients: 5

# %%
non_zero_coefs
# Out:
#              coefficient
# clinical_12    -0.133516
# clinical_14    -0.018599
# clinical_20     0.073261
# clinical_26    -0.006952
# clinical_48     0.158871

# %%
gcv.best_params_["coxnetsurvivalanalysis__alphas"][0]
# Out:
# 0.07784581144010294

# %%
gcv.best_params_["coxnetsurvivalanalysis__alphas"]
# Out:
# [0.07784581144010294]

# %% [markdown]
# ## For Radiomics

# %%
df = pd.read_csv('radiomics-train.csv')
df.head()
# Out:
#    Num      Patient  surv_status  surv_time  DF_surv_status  DF_surv_time  \
# 0    1  SICK0000022            0  20.866667               0     11.233333
# 1    2  SICK0000027            1  74.666667               0     31.600000
# 2    3  SICK0000053            1  58.633333               1     58.633333
# 3    4  SICK0000085            1  58.533333               1     58.533333
# 4    5  SICK0000213            0  40.433333               0     13.766667
#
#    DM_status    DM_time  IM_status    IM_time  ...  \
# 0          1  11.233333          0  20.866667  ...
# 1          0  74.666667          0  74.666667  ...
# 2          0  58.633333          0  58.633333  ...
# 3          0  58.533333          0  58.533333  ...
# 4          1  13.766667          1  13.766667  ...
#
#    original_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                           0.007047
# 1                                           0.017158
# 2                                           0.005932
# 3                                           0.007314
# 4                                           0.032357
#
#    original_gldm_LowGrayLevelEmphasis  original_gldm_SmallDependenceEmphasis  \
# 0                            0.005523                               0.893044
# 1                            0.013204                               0.881673
# 2                            0.004502                               0.892413
# 3                            0.006214                               0.907639
# 4                            0.014786                               0.829630
#
#    original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                         723.780508
# 1                                         375.646698
# 2                                         634.309034
# 3                                         798.071759
# 4                                         383.970267
#
#    original_gldm_SmallDependenceLowGrayLevelEmphasis  original_ngtdm_Busyness  \
# 0                                           0.005183                 0.021380
# 1                                           0.012330                 0.034383
# 2                                           0.004174                 0.025478
# 3                                           0.005984                 0.021264
# 4                                           0.010553                 0.022626
#
#    original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# 0                   0.040092                2175.588315
# 1                   0.048880                 890.006763
# 2                   0.034650                1651.539734
# 3                   0.034183                3366.444227
# 4                   0.071841                 997.527090
#
#    original_ngtdm_Contrast  original_ngtdm_Strength
# 0                 0.162204                46.800219
# 1                 0.111293                33.735629
# 2                 0.111554                35.270325
# 3                 0.176277                53.006708
# 4                 0.081362                92.718598
#
# [5 rows x 113 columns]

# %%
df["surv_status"]=df["surv_status"].astype(bool)
df["surv_status"]
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 278     True
# 279     True
# 280     True
# 281     True
# 282     True
# Name: surv_status, Length: 283, dtype: bool

# %%
df["DF_surv_status"]=df["DF_surv_status"].astype(bool)
df["DF_surv_status"]
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 278     True
# 279     True
# 280     True
# 281     True
# 282     True
# Name: DF_surv_status, Length: 283, dtype: bool

# %%
data=df.iloc[0:, 2:4]
data1=df.iloc[0:, 4:6]
X=df.iloc[0:, 10:]

y=data.to_records(index=False)
y1=data1.to_records(index=False)
X=OneHotEncoder().fit_transform(X)

# %%
y.shape
# Out:
# (283,)

# %%
X
# Out:
#      original_shape_Elongation  original_shape_MajorAxisLength  \
# 0                     0.652719                      295.129395
# 1                     0.635921                      363.259177
# 2                     0.503933                      490.105753
# 3                     0.762606                      317.414357
# 4                     0.830215                      404.746523
# ..                         ...                             ...
# 278                   0.676384                      736.165174
# 279                   0.921122                      375.291481
# 280                   0.689546                      411.964566
# 281                   0.788312                      359.353214
# 282                   0.358757                      953.203905
#
#      original_shape_Maximum2DDiameterColumn  \
# 0                                       224
# 1                                       272
# 2                                       359
# 3                                       248
# 4                                       279
# ..                                      ...
# 278                                     511
# 279                                     279
# 280                                     302
# 281                                     256
# 282                                     696
#
#      original_shape_Maximum2DDiameterRow  \
# 0                                    135
# 1                                    160
# 2                                    184
# 3                                    176
# 4                                    231
# ..                                   ...
# 278                                  368
# 279                                  248
# 280                                  199
# 281                                  213
# 282                                  240
#
#      original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                               227.903488                        227.903488
# 1                               275.697298                        275.697298
# 2                               365.242385                        365.242385
# 3                               258.938217                        258.938217
# 4                               295.040675                        295.040675
# ..                                     ...                               ...
# 278                             570.477870                        570.477870
# 279                             296.654681                        296.654681
# 280                             315.126959                        315.126959
# 281                             281.440935                        281.440935
# 282                             699.143047                        699.143047
#
#      original_shape_MeshVolume  original_shape_MinorAxisLength  \
# 0                   129.500000                      192.636689
# 1                   157.833333                      231.004258
# 2                   167.166667                      246.980671
# 3                   135.000000                      242.062199
# 4                   153.166667                      336.026565
# ..                         ...                             ...
# 278                 325.666667                      497.930448
# 279                 180.083333                      345.689111
# 280                 177.750000                      284.068371
# 281                 167.333333                      283.282315
# 282                 321.416667                      341.968748
#
#      original_shape_Sphericity  original_shape_SurfaceArea  ...  \
# 0                     0.123373                 1003.330870  ...
# 1                     0.117527                 1201.747845  ...
# 2                     0.115311                 1272.660114  ...
# 3                     0.124331                 1023.592600  ...
# 4                     0.120796                 1146.056308  ...
# ..                         ...                         ...  ...
# 278                   0.092428                 2476.652013  ...
# 279                   0.110191                 1399.541383  ...
# 280                   0.118421                 1291.006659  ...
# 281                   0.113709                 1291.444723  ...
# 282                   0.093227                 2434.015750  ...
#
#      original_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                             0.007047
# 1                                             0.017158
# 2                                             0.005932
# 3                                             0.007314
# 4                                             0.032357
# ..                                                 ...
# 278                                           0.006013
# 279                                           0.011991
# 280                                           0.007527
# 281                                           0.013186
# 282                                           0.605466
#
#      original_gldm_LowGrayLevelEmphasis  \
# 0                              0.005523
# 1                              0.013204
# 2                              0.004502
# 3                              0.006214
# 4                              0.014786
# ..                                  ...
# 278                            0.003195
# 279                            0.007280
# 280                            0.006379
# 281                            0.009188
# 282                            0.087272
#
#      original_gldm_SmallDependenceEmphasis  \
# 0                                 0.893044
# 1                                 0.881673
# 2                                 0.892413
# 3                                 0.907639
# 4                                 0.829630
# ..                                     ...
# 278                               0.825895
# 279                               0.884873
# 280                               0.907128
# 281                               0.871248
# 282                               0.794813
#
#      original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           723.780508
# 1                                           375.646698
# 2                                           634.309034
# 3                                           798.071759
# 4                                           383.970267
# ..                                                 ...
# 278                                         748.977914
# 279                                        2062.990295
# 280                                         890.829611
# 281                                         959.070026
# 282                                        1272.845602
#
#      original_gldm_SmallDependenceLowGrayLevelEmphasis  \
# 0                                             0.005183
# 1                                             0.012330
# 2                                             0.004174
# 3                                             0.005984
# 4                                             0.010553
# ..                                                 ...
# 278                                           0.002714
# 279                                           0.006138
# 280                                           0.006115
# 281                                           0.008543
# 282                                           0.036810
#
#      original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                   0.021380                   0.040092
# 1                   0.034383                   0.048880
# 2                   0.025478                   0.034650
# 3                   0.021264                   0.034183
# 4                   0.022626                   0.071841
# ..                       ...                        ...
# 278                 0.021351                   0.030575
# 279                 0.007575                   0.037120
# 280                 0.014100                   0.036346
# 281                 0.012909                   0.048066
# 282                 0.018061                   0.031220
#
#      original_ngtdm_Complexity  original_ngtdm_Contrast  \
# 0                  2175.588315                 0.162204
# 1                   890.006763                 0.111293
# 2                  1651.539734                 0.111554
# 3                  3366.444227                 0.176277
# 4                   997.527090                 0.081362
# ..                         ...                      ...
# 278                1072.168684                 0.062319
# 279                5496.584867                 0.336649
# 280                3738.501271                 0.128150
# 281                1610.794393                 0.141023
# 282                1943.345650                 0.179035
#
#      original_ngtdm_Strength
# 0                  46.800219
# 1                  33.735629
# 2                  35.270325
# 3                  53.006708
# 4                  92.718598
# ..                       ...
# 278                31.716504
# 279                99.614457
# 280                96.061014
# 281                53.954278
# 282                57.693158
#
# [283 rows x 103 columns]

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
X_std = stdsc.fit_transform(X)
print(X_std.shape)

X1 = pd.DataFrame(X_std)
# Out:
# (283, 103)

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X_mms = mms.fit_transform(X)
print(X_mms.shape)

X2 = pd.DataFrame(X_mms)
# Out:
# (283, 103)

# %% [markdown]
# ## surve time X1

# %%
def plot_coefficients(coefs, n_highlight):
    _, ax = plt.subplots(figsize=(9, 6))
    n_features = coefs.shape[0]
    alphas = coefs.columns
    for row in coefs.itertuples():
        ax.semilogx(alphas, row[1:], "-", label=row.Index)

    alpha_min = alphas.min()
    top_coefs = coefs.loc[:, alpha_min].map(abs).sort_values().tail(n_highlight)
    for name in top_coefs.index:
        coef = coefs.loc[name, alpha_min]
        #plt.text(
            #alpha_min, coef, name + "   ",
            #horizontalalignment="right",
            #verticalalignment="center"
        #)

    ax.yaxis.set_label_position("right")
    ax.yaxis.tick_right()
    ax.grid(True)
    ax.set_xlabel("alpha")
    ax.set_ylabel("coefficient")

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X1, y)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('figure1.jpg', dpi=1200)
plt.show()

# %% [markdown]
# ## surve time X2

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X2, y)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('figure2.jpg', dpi=1200)
plt.show()

# %% [markdown]
# ## surve time X1 & X2

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.exceptions import FitFailedWarning


coxnet_pipe = make_pipeline(
    StandardScaler(),
    CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01, max_iter=100000)
)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FitFailedWarning)
coxnet_pipe.fit(X1, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('coxnetsurvivalanalysis',
#                  CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=1.0))])

# %%
estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
cv = KFold(n_splits=5, shuffle=True, random_state=0)
gcv = GridSearchCV(
    make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=1.0)),
    param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
    cv=cv,
    error_score=0.5,
    n_jobs=4).fit(X1, y)

cv_results = pd.DataFrame(gcv.cv_results_)

# %%
alphas = cv_results.param_coxnetsurvivalanalysis__alphas.map(lambda x: x[0])
mean = cv_results.mean_test_score
std = cv_results.std_test_score

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(alphas, mean)
ax.fill_between(alphas, mean - std, mean + std, alpha=.15)
ax.set_xscale("log")
ax.set_ylabel("concordance index")
ax.set_xlabel("alpha")
ax.axvline(gcv.best_params_["coxnetsurvivalanalysis__alphas"][0], c="C1")
ax.axhline(0.5, color="grey", linestyle="--")
ax.grid(True)

#plt.savefig('figure3.jpg', dpi=1200)
plt.show()

# %%
best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
best_coefs = pd.DataFrame(
    best_model.coef_,
    index=X.columns,
    columns=["coefficient"]
)

non_zero = np.sum(best_coefs.iloc[:, 0] != 0)
print("Number of non-zero coefficients: {}".format(non_zero))

non_zero_coefs = best_coefs.query("coefficient != 0")
coef_order = non_zero_coefs.abs().sort_values("coefficient").index

_, ax = plt.subplots(figsize=(8, 8))
non_zero_coefs.loc[coef_order].plot.barh(ax=ax, legend=False)
ax.set_xlabel("coefficient")
ax.grid(True)

#plt.savefig('figure4.jpg', dpi=1200)
plt.show()
# Out:
# Number of non-zero coefficients: 3

# %%
best_coefs
# Out:
#                                         coefficient
# original_shape_Elongation                       0.0
# original_shape_MajorAxisLength                  0.0
# original_shape_Maximum2DDiameterColumn          0.0
# original_shape_Maximum2DDiameterRow             0.0
# original_shape_Maximum2DDiameterSlice           0.0
# ...                                             ...
# original_ngtdm_Busyness                         0.0
# original_ngtdm_Coarseness                       0.0
# original_ngtdm_Complexity                       0.0
# original_ngtdm_Contrast                         0.0
# original_ngtdm_Strength                         0.0
#
# [103 rows x 1 columns]

# %%
non_zero_coefs
# Out:
#                                                    coefficient
# original_glcm_Idn                                    -0.012222
# original_glrlm_RunLengthNonUniformityNormalized       0.085672
# original_gldm_LargeDependenceLowGrayLevelEmphasis    -0.046874

# %%
coef_order
# Out:
# Index(['original_glcm_Idn',
#        'original_gldm_LargeDependenceLowGrayLevelEmphasis',
#        'original_glrlm_RunLengthNonUniformityNormalized'],
#       dtype='object')

# %%
gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
# Out:
# CoxnetSurvivalAnalysis(alphas=[0.08666335279103955], l1_ratio=1.0)

# %% [markdown]
# ## DF surve time

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X1, y1)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('figure_1.jpg', dpi=1200)
plt.show()

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01)
cox_lasso.fit(X2, y1)

coefficients_lasso = pd.DataFrame(
    cox_lasso.coef_,
    index=X.columns,
    columns=np.round(cox_lasso.alphas_, 5)
)

plot_coefficients(coefficients_lasso, n_highlight=5)
#plt.savefig('figure_2.jpg', dpi=1200)
plt.show()

# %%
coxnet_pipe = make_pipeline(
    StandardScaler(),
    CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01, max_iter=100000)
)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FitFailedWarning)
coxnet_pipe.fit(X1, y1)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('coxnetsurvivalanalysis',
#                  CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=1.0))])

# %%
estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
cv = KFold(n_splits=5, shuffle=True, random_state=0)
gcv = GridSearchCV(
    make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=1.0)),
    param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
    cv=cv,
    error_score=0.5,
    n_jobs=4).fit(X1, y1)

cv_results = pd.DataFrame(gcv.cv_results_)

# %%
alphas = cv_results.param_coxnetsurvivalanalysis__alphas.map(lambda x: x[0])
mean = cv_results.mean_test_score
std = cv_results.std_test_score

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(alphas, mean)
ax.fill_between(alphas, mean - std, mean + std, alpha=.15)
ax.set_xscale("log")
ax.set_ylabel("concordance index")
ax.set_xlabel("alpha")
ax.axvline(gcv.best_params_["coxnetsurvivalanalysis__alphas"][0], c="C1")
ax.axhline(0.5, color="grey", linestyle="--")
ax.grid(True)

#plt.savefig('figure_3.jpg', dpi=1200)
plt.show()

# %%
best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
best_coefs = pd.DataFrame(
    best_model.coef_,
    index=X.columns,
    columns=["coefficient"]
)

non_zero = np.sum(best_coefs.iloc[:, 0] != 0)
print("Number of non-zero coefficients: {}".format(non_zero))

non_zero_coefs = best_coefs.query("coefficient != 0")
coef_order = non_zero_coefs.abs().sort_values("coefficient").index

_, ax = plt.subplots(figsize=(8, 8))
non_zero_coefs.loc[coef_order].plot.barh(ax=ax, legend=False)
ax.set_xlabel("coefficient")
ax.grid(True)

#plt.savefig('figure_4.jpg', dpi=1200)
plt.show()
# Out:
# Number of non-zero coefficients: 9

# %%
non_zero_coefs
# Out:
#                                                    coefficient
# original_firstorder_Kurtosis                         -0.015397
# original_firstorder_Median                            0.038338
# original_glcm_Idm                                    -0.002296
# original_glcm_Idmn                                   -0.002186
# original_glcm_Idn                                    -0.104787
# original_glcm_MaximumProbability                     -0.047772
# original_glszm_SmallAreaLowGrayLevelEmphasis         -0.020941
# original_gldm_DependenceNonUniformityNormalized       0.015440
# original_gldm_LargeDependenceLowGrayLevelEmphasis    -0.023054

# %%
gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
# Out:
# CoxnetSurvivalAnalysis(alphas=[0.04719616859770758], l1_ratio=1.0)
