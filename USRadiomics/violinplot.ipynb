# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('E:/Experiments/YulanPeng/Wenwen/OSDFS/Score-test.csv',encoding='gbk')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       40 non-null     int64
#  1   patient  40 non-null     object
#  2   2yOS     40 non-null     int64
#  3   3yOS     40 non-null     int64
#  4   5yOS     40 non-null     int64
#  5   2yDFS    40 non-null     int64
#  6   3yDFS    40 non-null     int64
#  7   5yDFS    40 non-null     int64
#  8   2OSCS    40 non-null     float64
#  9   2OSRS    40 non-null     float64
#  10  3OSCS    40 non-null     float64
#  11  3OSRS    40 non-null     float64
#  12  5OSCS    40 non-null     float64
#  13  5OSRS    40 non-null     float64
#  14  2DFSCS   40 non-null     float64
#  15  2DFSRS   40 non-null     float64
#  16  3DFSCS   40 non-null     float64
#  17  3DFSRS   40 non-null     float64
#  18  5DFSCS   40 non-null     float64
#  19  5DFSRS   40 non-null     float64
# ...

# %%
df.head()
# Out:
#    ID      patient  2yOS  3yOS  5yOS  2yDFS  3yDFS  5yDFS    2OSCS    2OSRS  \
# 0   1  SICK0000022     1     1     1      1      1      1  0.04214  0.00880
# 1   2  SICK0000027     1     1     1      1      1      1  0.06513  0.02870
# 2   4  SICK0000085     1     1     1      1      0      0  0.02262  0.01273
# 3   5  SICK0000213     1     1     1      1      1      1  0.05527  0.02916
# 4   6  SICK0000269     1     1     1      1      1      1  0.02550  0.06068
#
#      3OSCS    3OSRS    5OSCS    5OSRS   2DFSCS   2DFSRS   3DFSCS   3DFSRS  \
# 0  0.31009  0.00508  0.52944  0.17598  0.56772  0.18869  0.26724  0.57226
# 1  0.03775  0.16635  0.36407  0.23997  0.08050  0.24300  0.09761  0.59193
# 2  0.02038  0.02267  0.05297  0.16154  0.08006  0.22512  0.05720  0.37332
# 3  0.05056  0.02593  0.13798  0.23813  0.04107  0.06185  0.03496  0.15633
# 4  0.05321  0.10265  0.16299  0.56929  0.04895  0.44335  0.03982  0.20606
#
#     5DFSCS   5DFSRS
# 0  0.33953  0.32409
# 1  0.34309  0.56205
# ...

# %%
# Make boxplot for one group only
sns.violinplot(y=df["2OSCS"])
plt.show()

# %%
# Change line width
sns.violinplot(x=df["2yOS"], y=df["2OSCS"], linewidth=5)
plt.show()

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (6.0, 6.0)
sns.violinplot(x=df["2yOS"], y=df["2OSCS"], linewidth=5, width=0.8)
plt.savefig('2OSCS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["2yOS"], y=df["2OSRS"], linewidth=5, width=0.8)
plt.savefig('2OSRS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["2yDFS"], y=df["2DFSCS"], linewidth=5, width=0.8)
plt.savefig('2DFSCS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["2yDFS"], y=df["2DFSRS"], linewidth=5, width=0.8)
plt.savefig('2DFSRS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["3yOS"], y=df["3OSCS"], linewidth=5, width=0.8)
plt.savefig('3OSCS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["3yOS"], y=df["3OSRS"], linewidth=5, width=0.8)
plt.savefig('3OSRS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["3yDFS"], y=df["3DFSCS"], linewidth=5, width=0.8)
plt.savefig('3DFSCS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["3yDFS"], y=df["3DFSRS"], linewidth=5, width=0.8)
plt.savefig('3DFSRS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["5yOS"], y=df["5OSCS"], linewidth=5, width=0.8)
plt.savefig('5OSCS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["5yOS"], y=df["5OSRS"], linewidth=5, width=0.8)
plt.savefig('5OSRS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["5yDFS"], y=df["5DFSRS"], linewidth=5, width=0.8)
plt.savefig('5DFSRS.jpg',dpi=1200)
plt.show()

# %%
sns.violinplot(x=df["5yDFS"], y=df["5DFSCS"], linewidth=5, width=0.8)
plt.savefig('5DFSCS.jpg',dpi=1200)
plt.show()
